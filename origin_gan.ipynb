# %%
from steganogan import SteganoGAN
steganogan = SteganoGAN.load(architecture='basic')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 from steganogan import SteganoGAN
# ----> 2 steganogan = SteganoGAN.load(architecture='basic')
#
# File ~\Testplace\steganography_gan\.venv\Lib\site-packages\steganogan\models.py:364, in SteganoGAN.load(cls, architecture, path, cuda, verbose)
#     360 elif (architecture is None and path is None) or (architecture and path):
#     361     raise ValueError(
#     362         'Please provide either an architecture or a path to pretrained model.')
# --> 364 steganogan = torch.load(path, map_location='cpu')
#     365 steganogan.verbose = verbose
#     367 steganogan.encoder.upgrade_legacy()
#
# File ~\Testplace\steganography_gan\.venv\Lib\site-packages\torch\serialization.py:1494, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1487         return _legacy_load(
#    1488             opened_file,
#    1489             map_location,
#    1490             _weights_only_unpickler,
#    1491             **pickle_load_args,
#    1492         )
#    1493     except pickle.UnpicklingError as e:
# -> 1494         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
#    1495 return _legacy_load(
#    1496     opened_file, map_location, pickle_module, **pickle_load_args
#    1497 )
#
# UnpicklingError: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL steganogan.models.SteganoGAN was not an allowed global by default. Please use `torch.serialization.add_safe_globals([SteganoGAN])` or the `torch.serialization.safe_globals([SteganoGAN])` context manager to allowlist this global if you trust this class/function.
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.

# %%
steganogan.encode('research/input.png', 'research/output.png', 'This is a super secret message!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 steganogan.encode('research/input.png', 'research/output.png', 'This is a super secret message!')
#
# NameError: name 'steganogan' is not defined
